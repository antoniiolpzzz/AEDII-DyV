# %% [markdown]
# # GRAFICA CONTRASTE CASO I - TEORICO
# # M VARIABLE

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# GRAFICA PROMEDIOS I
dataCI = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# Separar los datos en n y tiempo
n = dataCI[:, 0]
tiempo = dataCI[:, 1]

# Función de ajuste O(n*log(n))
def func(n, a, b):
    return a * n * n + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)

# Parámetros del ajuste
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.scatter(n, tiempo, label='Estudio experimental: t(n)', color = 'blue', alpha = 0.3)
plt.plot(n, func(n, *popt), color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Estudio teórico: O(n^2) vs Estudio experimental: O(t(n))')
plt.legend()
plt.grid(true)
plt.show()

# %% [markdown]
# # GRAFICA CONTRASTE CASO N/1000 CASO II N/500 CASO III N/2000

# %%
dataCIN2000 = np.array([
 [10000, 0.001052, 5],
[20000, 0.003571, 10],
[30000, 0.00773, 15],
[40000, 0.013444, 20],
[50000, 0.020723, 25],
[60000, 0.029163, 30],
[70000, 0.039369, 35],
[80000, 0.05088, 40],
[90000, 0.063954, 45],
[100000, 0.079032, 50],
[110000, 0.095697, 55],
[120000, 0.114032, 60],
[130000, 0.133833, 65],
[140000, 0.154961, 70],
[150000, 0.178406, 75],
[160000, 0.202041, 80],
[170000, 0.22793, 85],
[180000, 0.25689, 90],
[190000, 0.290841, 95],
[200000, 0.317933, 100],
[210000, 0.362074, 105],
[220000, 0.387391, 110],
[230000, 0.424225, 115],
[240000, 0.462997, 120],
[250000, 0.50264, 125],
[260000, 0.53723, 130],
[270000, 0.582189, 135],
[280000, 0.619579, 140],
[290000, 0.664409, 145],
[300000, 0.713727, 150],
[310000, 0.759061, 155],
[320000, 0.822785, 160],
[330000, 0.869151, 165],
[340000, 0.9167, 170],
[350000, 0.967353, 175],
[360000, 1.03917, 180],
[370000, 1.09543, 185],
[380000, 1.14766, 190],
[390000, 1.22397, 195],
[400000, 1.27973, 200],
[410000, 1.34811, 205],
[420000, 1.39844, 210],
[430000, 1.46338, 215],
[440000, 1.53939, 220],
[450000, 1.63801, 225],
[460000, 1.68842, 230],
[470000, 1.7786, 235],
[480000, 1.84854, 240],
[490000, 1.91188, 245],
[500000, 2.00481, 250],
[510000, 2.07424, 255],
[520000, 2.14861, 260],
[530000, 2.22979, 265],
[540000, 2.33908, 270],
[550000, 2.43398, 275],
[560000, 2.50835, 280],
[570000, 2.56659, 285],
[580000, 2.68878, 290],
[590000, 2.79829, 295],
[600000, 2.89169, 300],
[610000, 2.99551, 305],
[620000, 3.1495, 310],
[630000, 3.19608, 315],
[640000, 3.27815, 320],
[650000, 3.39111, 325],
[660000, 3.50472, 330],
[670000, 3.60469, 335],
[680000, 3.72757, 340],
[690000, 3.84598, 345],
[700000, 3.92733, 350],
[710000, 4.04389, 355],
[720000, 4.15653, 360],
[730000, 4.24033, 365],
[740000, 4.39417, 370],
[750000, 4.52533, 375],
[760000, 4.60263, 380],
[770000, 4.76781, 385],
[780000, 4.88632, 390],
[790000, 4.99953, 395],
[800000, 5.14219, 400],
[810000, 5.25592, 405],
[820000, 5.39792, 410],
[830000, 5.51299, 415],
[840000, 5.64184, 420],
[850000, 5.81642, 425],
[860000, 5.95085, 430],
[870000, 6.07056, 435],
[880000, 6.22468, 440],
[890000, 6.37502, 445],
[900000, 6.52205, 450],
[910000, 6.64996, 455],
[920000, 6.8129, 460],
[930000, 6.90239, 465],
[940000, 7.08247, 470],
[950000, 7.24258, 475],
[960000, 7.4447, 480],
[970000, 7.55569, 485],
[980000, 7.71527, 490],
[990000, 7.88323, 495],
[1000000, 8.05726, 500]

])

nN2000 = dataCIN2000[:, 0]
tiempoN2000 = dataCIN2000[:, 1]

# %%
dataCIN500 = np.array([
    [10000, 0.003409, 20],
[20000, 0.013063, 40],
[30000, 0.028949, 60],
[40000, 0.051444, 80],
[50000, 0.080537, 100],
[60000, 0.115801, 120],
[70000, 0.157982, 140],
[80000, 0.204615, 160],
[90000, 0.258477, 180],
[100000, 0.321371, 200],
[110000, 0.385342, 220],
[120000, 0.459786, 240],
[130000, 0.540502, 260],
[140000, 0.626517, 280],
[150000, 0.716292, 300],
[160000, 0.81753, 320],
[170000, 0.936019, 340],
[180000, 1.04974, 360],
[190000, 1.15492, 380],
[200000, 1.28578, 400],
[210000, 1.40139, 420],
[220000, 1.54883, 440],
[230000, 1.69892, 460],
[240000, 1.84822, 480],
[250000, 2.0072, 500],
[260000, 2.16401, 520],
[270000, 2.33922, 540],
[280000, 2.51229, 560],
[290000, 2.70596, 580],
[300000, 2.86733, 600],
[310000, 3.09541, 620],
[320000, 3.26758, 640],
[330000, 3.5007, 660],
[340000, 3.7104, 680],
[350000, 3.9203, 700],
[360000, 4.14187, 720],
[370000, 4.40104, 740],
[380000, 4.65121, 760],
[390000, 4.85075, 780],
[400000, 5.14609, 800],
[410000, 5.44536, 820],
[420000, 5.61938, 840],
[430000, 5.91817, 860],
[440000, 6.21832, 880],
[450000, 6.49337, 900],
[460000, 6.79436, 920],
[470000, 7.08553, 940],
[480000, 7.41198, 960],
[490000, 7.76246, 980],
[500000, 8.09187, 1000],
[510000, 8.40254, 1020],
[520000, 8.70606, 1040],
[530000, 9.05225, 1060],
[540000, 9.38771, 1080],
[550000, 9.72738, 1100],
[560000, 10.1426, 1120],
[570000, 10.4792, 1140],
[580000, 10.8425, 1160],
[590000, 11.2241, 1180],
[600000, 11.6214, 1200],
[610000, 11.9976, 1220],
[620000, 12.3916, 1240],
[630000, 12.7981, 1260],
[640000, 13.2178, 1280],
[650000, 13.6582, 1300],
[660000, 14.0729, 1320],
[670000, 14.5641, 1340],
[680000, 14.9995, 1360],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# Separar los datos en n y tiempo
n = dataCI[:, 0]
tiempo = dataCI[:, 1]

# Función de ajuste O(n*log(n))
def func(n, a, b):
    return a * n * n + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)

# Parámetros del ajuste
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.scatter(nN500, tiempoN500, label='Estudio experimental: t(n) M=N/500', color = 'red', alpha = 0.3)
plt.scatter(n, tiempo, label='Estudio experimental: t(n) M=N/1000', color = 'blue', alpha = 0.3)
plt.scatter(nN2000, tiempoN2000, label='Estudio experimental: t(n) M=N/2000', color = 'green', alpha = 0.3)


#plt.plot(n, func(n, *popt)+0.7, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Estudio experimental: Variación de la razón de M')
plt.legend()
plt.grid(True)
plt.show()

# %%
dataCIM100 = np.array(
    [
        [10000, 0.017917, 100],
[20000, 0.035851, 100],
[30000, 0.063404, 100],
[40000, 0.071263, 100],
[50000, 0.079306, 100],
[60000, 0.127342, 100],
[70000, 0.134639, 100],
[80000, 0.142219, 100],
[90000, 0.14996, 100],
[100000, 0.158564, 100],
[110000, 0.245896, 100],
[120000, 0.254217, 100],
[130000, 0.27244, 100],
[140000, 0.277504, 100],
[150000, 0.278002, 100],
[160000, 0.285626, 100],
[170000, 0.292122, 100],
[180000, 0.300107, 100],
[190000, 0.30802, 100],
[200000, 0.316249, 100],
[210000, 0.486979, 100],
[220000, 0.492559, 100],
[230000, 0.499669, 100],
[240000, 0.517226, 100],
[250000, 0.516005, 100],
[260000, 0.523555, 100],
[270000, 0.531649, 100],
[280000, 0.540622, 100],
[290000, 0.549497, 100],
[300000, 0.55985, 100],
[310000, 0.570731, 100],
[330000, 3.29153, 500],
[340000, 3.32148, 500],
[350000, 3.35929, 500],
[360000, 3.39901, 500],
[370000, 3.49764, 500],
[380000, 3.54236, 500],
[390000, 3.58193, 500],
[400000, 3.62292, 500],
[410000, 3.66281, 500],
[420000, 3.70149, 500],
[430000, 3.74057, 500],
[440000, 3.78285, 500],
[450000, 3.7708, 500],
[460000, 3.81749, 500],
[470000, 3.90004, 500],
[480000, 3.94016, 500],
[490000, 3.98076, 500],
[500000, 4.01965, 500],
[510000, 4.05841, 500],
[520000, 6.08377, 500],
[530000, 6.0594, 500],
[540000, 6.09894, 500],
[550000, 6.13969, 500],
[560000, 6.17804, 500],
[570000, 6.24582, 500],
[580000, 6.37438, 500],
[590000, 6.41206, 500],
[600000, 6.45145, 500],
[610000, 6.49198, 500],
[620000, 6.53336, 500],
[630000, 6.57365, 500],
[640000, 6.61453, 500],
[650000, 6.65344, 500],
[660000, 6.65648, 500],
[670000, 6.60562, 500],
[680000, 6.64358, 500],
[690000, 6.68996, 500],
[700000, 6.79163, 500],
[710000, 6.82777, 500],
[720000, 6.91266, 500],
[730000, 6.97194, 500],
[740000, 7.01078, 500],
[750000, 7.04929, 500],
[760000, 7.08781, 500],
[770000, 7.12799, 500],
[780000, 7.12692, 500],
[790000, 7.11865, 500],
[800000, 7.21932, 500],
[810000, 7.20097, 500],
[820000, 7.31989, 500],
[830000, 7.36836, 500],
[840000, 7.29046, 500],
[850000, 7.31216, 500],
[860000, 7.44521, 500],
[870000, 7.44333, 500],
[880000, 7.42586, 500],
[890000, 7.46577, 500],
[900000, 7.50605, 500],
[910000, 7.54244, 500],
[920000, 7.58114, 500],
[930000, 7.63613, 500],
[940000, 7.81134, 500],
[950000, 7.75488, 500],
[960000, 7.88557, 500],
[970000, 7.92593, 500],
[980000, 7.96622, 500],
[990000, 8.00459, 500],
[1000000, 8.04323, 500]
    ]
)
nM500 = dataCIM500[:, 0]
tiempoM500 = dataCIM500[:, 1]

# %%
dataCIM1000 = np.array( [
    [10000, 0.187888, 1000],
[20000, 0.390174, 1000],
[30000, 0.472635, 1000],
[40000, 0.804478, 1000],
[50000, 0.882588, 1000],
[60000, 0.97107, 1000],
[70000, 1.54472, 1000],
[80000, 1.61394, 1000],
[90000, 1.71017, 1000],
[100000, 1.79593, 1000],
[110000, 1.87702, 1000],
[120000, 1.95446, 1000],
[130000, 3.02781, 1000],
[140000, 3.07457, 1000],
[150000, 3.15247, 1000],
[160000, 3.22998, 1000],
[170000, 3.30814, 1000],
[180000, 3.38631, 1000],
[190000, 3.46444, 1000],
[200000, 3.54296, 1000],
[210000, 3.62073, 1000],
[220000, 3.69887, 1000],
[230000, 3.77709, 1000],
[240000, 3.85534, 1000],
[250000, 3.93303, 1000],
[260000, 6.04426, 1000],
[270000, 6.20367, 1000],
[280000, 6.28221, 1000],
[290000, 6.34539, 1000],
[300000, 6.32812, 1000],
[310000, 6.39961, 1000],
[320000, 6.5402, 1000],
[330000, 6.60461, 1000],
[340000, 6.75525, 1000],
[350000, 6.83032, 1000],
[360000, 6.82923, 1000],
[370000, 6.91517, 1000],
[380000, 7.02412, 1000],
[390000, 7.11186, 1000],
[400000, 7.21012, 1000],
[410000, 7.30851, 1000],
[420000, 7.39706, 1000],
[430000, 7.45102, 1000],
[440000, 7.43978, 1000],
[450000, 7.52137, 1000],
[460000, 7.66696, 1000],
[470000, 7.68445, 1000],
[480000, 7.78937, 1000],
[490000, 7.81236, 1000],
[500000, 7.8885, 1000],
[510000, 8.00981, 1000],
[520000, 12.1301, 1000],
[530000, 12.2998, 1000],
[540000, 12.3349, 1000],
[550000, 12.3918, 1000],
[560000, 12.4828, 1000],
[570000, 12.5532, 1000],
[580000, 12.5586, 1000],
[590000, 12.6099, 1000],
[600000, 12.7111, 1000],
[610000, 12.7648, 1000],
[620000, 12.9371, 1000],
[630000, 13.1381, 1000],
[640000, 13.2156, 1000],
[650000, 13.2968, 1000],
[660000, 13.1671, 1000],
[670000, 13.4586, 1000],
[680000, 13.51, 1000],
[690000, 13.6152, 1000],
[700000, 13.5869, 1000],
[710000, 13.5176, 1000],
[720000, 13.7264, 1000],
[730000, 13.7751, 1000],
[740000, 13.9272, 1000],
[750000, 14.0025, 1000],
[760000, 14.0411, 1000],
[770000, 14.0719, 1000],
[780000, 14.2196, 1000],
[790000, 14.4074, 1000],
[800000, 14.3426, 1000],
[810000, 14.4087, 1000],
[820000, 14.4715, 1000],
[830000, 14.6802, 1000],
[840000, 14.761, 1000],
[850000, 14.8407, 1000],
[860000, 14.6886, 1000],
[870000, 14.8682, 1000],
[880000, 15.0774, 1000],
[890000, 15.2131, 1000],
[900000, 15.2584, 1000],
[910000, 15.2672, 1000],
[920000, 15.458, 1000],
[930000, 15.4802, 1000],
[940000, 15.5414, 1000],
[950000, 15.6649, 1000],
[960000, 15.7676, 1000],
[970000, 15.9426, 1000],
[980000, 15.7091, 1000],
[990000, 15.8992, 1000],
[1000000, 15.9593, 1000]

]
)


nM1000 = dataCIM1000[:, 0]
tiempoM1000 = dataCIM1000[:, 1]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


dataCIM10 = np.array( [
[10000, 0.005964, 10],
[20000, 0.011788, 10],
[30000, 0.018982, 10],
[40000, 0.015568, 10],
[50000, 0.01741, 10],
[60000, 0.01458, 10],
[70000, 0.012935, 10],
[80000, 0.014199, 10],
[90000, 0.021252, 10],
[100000, 0.021999, 10],
[110000, 0.022837, 10],
[120000, 0.023705, 10],
[130000, 0.02409, 10],
[140000, 0.025334, 10],
[150000, 0.026024, 10],
[160000, 0.028533, 10],
[170000, 0.034512, 10],
[180000, 0.042869, 10],
[190000, 0.043007, 10],
[200000, 0.04352, 10],
[210000, 0.045197, 10],
[220000, 0.045591, 10],
[230000, 0.04559, 10],
[240000, 0.047779, 10],
[250000, 0.048713, 10],
[260000, 0.048165, 10],
[270000, 0.049288, 10],
[280000, 0.050353, 10],
[290000, 0.050881, 10],
[300000, 0.052437, 10],
[310000, 0.055442, 10],
[320000, 0.057098, 10],
[330000, 0.060244, 10],
[340000, 0.068641, 10],
[350000, 0.078189, 10],
[360000, 0.085522, 10],
[370000, 0.087613, 10],
[380000, 0.085676, 10],
[390000, 0.085611, 10],
[400000, 0.086552, 10],
[410000, 0.087961, 10],
[420000, 0.090144, 10],
[430000, 0.090487, 10],
[440000, 0.090517, 10],
[450000, 0.091619, 10],
[460000, 0.091931, 10],
[470000, 0.092404, 10],
[480000, 0.094127, 10],
[490000, 0.095356, 10],
[500000, 0.095597, 10],
[510000, 0.095599, 10],
[520000, 0.096996, 10],
[530000, 0.096514, 10],
[540000, 0.098025, 10],
[550000, 0.099628, 10],
[560000, 0.10093, 10],
[570000, 0.100676, 10],
[580000, 0.100708, 10],
[590000, 0.101216, 10],
[600000, 0.104018, 10],
[610000, 0.115767, 10],
[620000, 0.117634, 10],
[630000, 0.122402, 10],
[640000, 0.116452, 10],
[650000, 0.114982, 10],
[660000, 0.12003, 10],
[670000, 0.12821, 10],
[680000, 0.136467, 10],
[690000, 0.144696, 10],
[700000, 0.153242, 10],
[710000, 0.161653, 10],
[720000, 0.170313, 10],
[730000, 0.170641, 10],
[740000, 0.170759, 10],
[750000, 0.170722, 10],
[760000, 0.171602, 10],
[770000, 0.173153, 10],
[780000, 0.17072, 10],
[790000, 0.172351, 10],
[800000, 0.172952, 10],
[810000, 0.174332, 10],
[820000, 0.175974, 10],
[830000, 0.177938, 10],
[840000, 0.18226, 10],
[850000, 0.183212, 10],
[860000, 0.181323, 10],
[870000, 0.182615, 10],
[880000, 0.181003, 10],
[890000, 0.180982, 10],
[900000, 0.181025, 10],
[910000, 0.18098, 10],
[920000, 0.181457, 10],
[930000, 0.182948, 10],
[940000, 0.184401, 10],
[950000, 0.18598, 10],
[960000, 0.187434, 10],
[970000, 0.189104, 10],
[980000, 0.190588, 10],
[990000, 0.191162, 10],
[1000000, 0.190994, 10]
    ])


nM10 = dataCIM10[:, 0]
tiempoM10 = dataCIM10[:, 1]



plt.scatter(n, tiempo, label='Estudio experimental: t(n) MVARIABLE', color = 'blue', alpha = 0.3)
plt.scatter(nM10, tiempoM10, label='Estudio experimental: t(n) M10', color = 'red', alpha = 0.3)
plt.scatter(nM100, tiempoM100, label='Estudio experimental: t(n) M100', color = 'green', alpha = 0.3)
plt.scatter(nM500, tiempoM500, label='Estudio experimental: t(n) M500', color = 'yellow', alpha = 0.3)
plt.scatter(nM1000, tiempoM1000, label='Estudio experimental: t(n) M1000', color = 'pink', alpha = 0.3)
#plt.plot(n, func(n, *popt)+0.7, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Estudio experimental: M/1000 vs M=10 vs M=100 vs M=500 vs M=1000')
plt.legend()
plt.show()
