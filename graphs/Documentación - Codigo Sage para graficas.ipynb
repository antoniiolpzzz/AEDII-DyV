# %%
#EJECUCION OBLIGATORIA

import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

#ADEMAS SE RECOMIENDA EJECUTAR LA TOTALIDAD DEL NOTEBOOK DE MANERA ORDENADA PARA NO EXPERIMENTAR FALLOS

# %% [markdown]
# # Estudio experimental
# # GRAFICA I

# %%
data = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# %%
# EJECUTAR VARIABLES ANTERIORES Y ESTE CODIGO
n = data[:, 0]
tiempo = data[:, 1]

# Graficar datos experimentales
plt.scatter(n, tiempo, label='Estudio experimental: t(n)', color = 'blue', alpha = 0.3)
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Estudio experimental')
plt.legend()
plt.grid(true)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Estudio experimental: Variación de la razón de M
# # GRAFICA III

# %%
dataCIN500 = np.array([
    [10000, 0.003409, 20],
[20000, 0.013063, 40],
[30000, 0.028949, 60],
[40000, 0.051444, 80],
[50000, 0.080537, 100],
[60000, 0.115801, 120],
[70000, 0.157982, 140],
[80000, 0.204615, 160],
[90000, 0.258477, 180],
[100000, 0.321371, 200],
[110000, 0.385342, 220],
[120000, 0.459786, 240],
[130000, 0.540502, 260],
[140000, 0.626517, 280],
[150000, 0.716292, 300],
[160000, 0.81753, 320],
[170000, 0.936019, 340],
[180000, 1.04974, 360],
[190000, 1.15492, 380],
[200000, 1.28578, 400],
[210000, 1.40139, 420],
[220000, 1.54883, 440],
[230000, 1.69892, 460],
[240000, 1.84822, 480],
[250000, 2.0072, 500],
[260000, 2.16401, 520],
[270000, 2.33922, 540],
[280000, 2.51229, 560],
[290000, 2.70596, 580],
[300000, 2.86733, 600],
[310000, 3.09541, 620],
[320000, 3.26758, 640],
[330000, 3.5007, 660],
[340000, 3.7104, 680],
[350000, 3.9203, 700],
[360000, 4.14187, 720],
[370000, 4.40104, 740],
[380000, 4.65121, 760],
[390000, 4.85075, 780],
[400000, 5.14609, 800],
[410000, 5.44536, 820],
[420000, 5.61938, 840],
[430000, 5.91817, 860],
[440000, 6.21832, 880],
[450000, 6.49337, 900],
[460000, 6.79436, 920],
[470000, 7.08553, 940],
[480000, 7.41198, 960],
[490000, 7.76246, 980],
[500000, 8.09187, 1000],
[510000, 8.40254, 1020],
[520000, 8.70606, 1040],
[530000, 9.05225, 1060],
[540000, 9.38771, 1080],
[550000, 9.72738, 1100],
[560000, 10.1426, 1120],
[570000, 10.4792, 1140],
[580000, 10.8425, 1160],
[590000, 11.2241, 1180],
[600000, 11.6214, 1200],
[610000, 11.9976, 1220],
[620000, 12.3916, 1240],
[630000, 12.7981, 1260],
[640000, 13.2178, 1280],
[650000, 13.6582, 1300],
[660000, 14.0729, 1320],
[670000, 14.5641, 1340],
[680000, 14.9995, 1360],
[690000, 15.368, 1380],
[700000, 15.8797, 1400],
[710000, 16.2819, 1420],
[720000, 16.8637, 1440],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# %%
# Separar los datos en N y tiempo
n = dataCI[:, 0]
tiempo = dataCI[:, 1]

# Función de ajuste
def func(n, a, b):
    return a * n * n + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.scatter(nN500, tiempoN500, label='Estudio experimental: t(n) M=N/500', color = 'red', alpha = 0.3)
plt.scatter(n, tiempo, label='Estudio experimental: t(n) M=N/1000', color = 'blue', alpha = 0.3)
plt.scatter(nN2000, tiempoN2000, label='Estudio experimental: t(n) M=N/2000', color = 'green', alpha = 0.3)


plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Estudio experimental: Variación de la razón de M')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Estudio experimental:  CASO PRUEBA I vs CASO PRUEBA II
# # GRAFICA III

# %%
data_str = """10000,0.009008,10
20000,0.020934,20
30000,0.028289,30
40000,0.031273,40
50000,0.039427,50
60000,0.056851,60
70000,0.077351,70
80000,0.105474,80
90000,0.130615,90
100000,0.157952,100
110000,0.191616,110
120000,0.228245,120
130000,0.268406,130
140000,0.309143,140
150000,0.355267,150
160000,0.403734,160
170000,0.455525,170
180000,0.510954,180
190000,0.569696,190
200000,0.631222,200
210000,0.700666,210
220000,0.776997,220
230000,0.836924,230
240000,0.912075,240
250000,0.996781,250
260000,1.0668,260
270000,1.15052,270
280000,1.24496,280
290000,1.33624,290
300000,1.44153,300
310000,1.52793,310
320000,1.61974,320
330000,1.73209,330
340000,1.83736,340
350000,1.95101,350
360000,2.07653,360
370000,2.18598,370
380000,2.29028,380
390000,2.4319,390
400000,2.56997,400
410000,2.7043,410
420000,2.82569,420
430000,2.95689,430
440000,3.09989,440
450000,3.23977,450
460000,3.38578,460
470000,3.51922,470
480000,3.69369,480
490000,3.82838,490
500000,3.98685,500
510000,4.12481,510
520000,4.48608,520
530000,4.65144,530
540000,4.83313,540
550000,4.85624,550
560000,5.03495,560
570000,5.31466,570
580000,5.38346,580
590000,5.56782,590
600000,5.80675,600
610000,6.01638,610
620000,6.14012,620
630000,6.31868,630
640000,6.76055,640
650000,6.73834,650
660000,7.03942,660
670000,7.25048,670
680000,7.54454,680
690000,7.63723,690
700000,7.91233,700
710000,8.08499,710
720000,8.31053,720
730000,8.51646,730
740000,8.76753,740
750000,9.04461,750
760000,9.23619,760
770000,9.49979,770
780000,9.7556,780
790000,9.94828,790
800000,10.2386,800
810000,10.5176,810
820000,10.9457,820
830000,11.1578,830
840000,11.3374,840
850000,11.5965,850
860000,11.8614,860
870000,12.0717,870
880000,12.3858,880
890000,12.686,890
900000,13.0095,900
910000,13.2524,910
920000,13.4955,920
930000,13.9364,930
940000,14.2004,940
950000,14.5173,950
960000,14.7554,960
970000,15.1293,970
980000,15.4406,980
990000,15.7627,990
1000000,16.1673,1000"""

lines = data_str.split('\n')

data = [[float(val) for val in line.split(',')] for line in lines]

data_array = np.array(data)

# %%
data = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# %%
# Separar los datos en n y tiempo
n = data[:, 0]
tiempo = data[:, 1]

dataII = data_array

nII = dataII[:, 1]
tiempoII = dataII[:, 1]

# Función de ajuste
def func(n, a, b):
    return a * n * n + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.plot(n, tiempo, label='Estudio experimental: t(n) CASO I', color = 'blue', alpha = 0.5)
plt.plot(n, tiempoII, label='Estudio experimental: t(n) CASO II', color = 'red', alpha = 0.6)

#plt.plot(n, func(n, *popt)+0.7, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Experimental: CASO PRUEBA I vs CASO PRUEBA II')
plt.legend()
plt.grid(true)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------

# %% [markdown]
# # Estudio experimental: Contraste teorico - experimental
# # GRAFICA IV

# %%
data = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# %%
n = data[:, 0]
tiempo = data[:, 1]

# Función de ajuste
def func(n, a, b):
    return a * n^2 + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)
a, b = popt

factor = 1.5

# Graficar datos experimentales y curva ajustada
plt.scatter(n, tiempo, label='Estudio experimental: t(n)', color = 'blue', alpha = 0.3)
plt.plot(n, func(n, *popt)+factor, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Estudio teorico(O(n^2)) vs Estudio experimental(O(t(n))) ')
plt.legend()
plt.grid(true)
plt.show()

# %% [markdown]
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------
