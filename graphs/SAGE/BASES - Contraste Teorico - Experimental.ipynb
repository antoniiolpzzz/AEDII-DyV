# %%
import numpy as np
import matplotlib.pyplot as plt

# Datos proporcionados
DatosPROMEDIO = [
        [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]

]

DatosMEJOR = [
    [10000, 0.005223, 10],
    [20000, 0.015976, 20],
    [30000, 0.025862, 30],
    # Resto de los datos...
]

DatosPEOR = [
    [10000, 0.004556, 10],
    [20000, 0.014749, 20],
    [30000, 0.024013, 30],
    # Resto de los datos...
]

# Ordenar los datos por el primer columna (Tamaño)
PromedioOrdenados = sorted(DatosPROMEDIO, key=lambda x: x[0])
MejorOrdenados = sorted(DatosMEJOR, key=lambda x: x[0])
PeorOrdenados = sorted(DatosPEOR, key=lambda x: x[0])

# Obtener las dos primeras columnas como datos x e y
xP, yP = zip(*[(row[0], row[1]) for row in PromedioOrdenados])
#xB, yB = zip(*[(row[0], row[1]) for row in MejorOrdenados])
#xW, yW = zip(*[(row[0], row[1]) for row in PeorOrdenados])

# Función teórica
xTeorico = np.logspace(4, 6, 1000) # Evitamos el 0 para evitar el log(0)
yTeorico = xTeorico * np.log(xTeorico) * 1/xTeorico

# Crear el gráfico de líneas
plt.plot(xP, yP, 'bo', markersize=1, linewidth=2, label='Promedio')
#plt.plot(xB, yB, 'ro', markersize=1, linewidth=2, label='Mejor')
#plt.plot(xW, yW, 'go', markersize=1, linewidth=2, label='Peor')
plt.plot(xTeorico, yTeorico, label='Función Teórica')

# Etiquetas y título
plt.xlabel('Tamaño')
plt.ylabel('Tiempo')
plt.title('Gráfico de Líneas (Datos Ordenados Ascendentemente)')
plt.legend()

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# GRAFICA PROMEDIOS I
data = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# Separar los datos en n y tiempo
n = data[:, 0]
tiempo = data[:, 1]

# Función de ajuste O(n*log(n))
def func(n, a, b):
    return a * n * n + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)

# Parámetros del ajuste
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.scatter(n, tiempo, label='Estudio experimental: t(n)', color = 'blue', alpha = 0.3)
plt.plot(n, func(n, *popt)+0.7, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Teorico(O(n^2)) vs Experimental(O(t(n))) ')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# GRAFICA PROMEDIOS I
data = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

# Separar los datos en n y tiempo
n = data[:, 0]
tiempo = data[:, 1]

# Función de ajuste O(n*log(n))
def func(n, a, b):
    return a * n^2 + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)

# Parámetros del ajuste
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.scatter(n, tiempo, label='Estudio experimental: t(n)', color = 'blue', alpha = 0.3)
plt.plot(n, func(n, *popt)+1, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Teorico(O(n^2)) vs Experimental(O(t(n))) ')
plt.legend()
plt.show()

# %%
import numpy as np

data_str = """10000,0.009008,10
20000,0.020934,20
30000,0.028289,30
40000,0.031273,40
50000,0.039427,50
60000,0.056851,60
70000,0.077351,70
80000,0.105474,80
90000,0.130615,90
100000,0.157952,100
110000,0.191616,110
120000,0.228245,120
130000,0.268406,130
140000,0.309143,140
150000,0.355267,150
160000,0.403734,160
170000,0.455525,170
180000,0.510954,180
190000,0.569696,190
200000,0.631222,200
210000,0.700666,210
220000,0.776997,220
230000,0.836924,230
240000,0.912075,240
250000,0.996781,250
260000,1.0668,260
270000,1.15052,270
280000,1.24496,280
290000,1.33624,290
300000,1.44153,300
310000,1.52793,310
320000,1.61974,320
330000,1.73209,330
340000,1.83736,340
350000,1.95101,350
360000,2.07653,360
370000,2.18598,370
380000,2.29028,380
390000,2.4319,390
400000,2.56997,400
410000,2.7043,410
420000,2.82569,420
430000,2.95689,430
440000,3.09989,440
450000,3.23977,450
460000,3.38578,460
470000,3.51922,470
480000,3.69369,480
490000,3.82838,490
500000,3.98685,500
510000,4.12481,510
520000,4.48608,520
530000,4.65144,530
540000,4.83313,540
550000,4.85624,550
560000,5.03495,560
570000,5.31466,570
580000,5.38346,580
590000,5.56782,590
600000,5.80675,600
610000,6.01638,610
620000,6.14012,620
630000,6.31868,630
640000,6.76055,640
650000,6.73834,650
660000,7.03942,660
670000,7.25048,670
680000,7.54454,680
690000,7.63723,690
700000,7.91233,700
710000,8.08499,710
720000,8.31053,720
730000,8.51646,730
740000,8.76753,740
750000,9.04461,750
760000,9.23619,760
770000,9.49979,770
780000,9.7556,780
790000,9.94828,790
800000,10.2386,800
810000,10.5176,810
820000,10.9457,820
830000,11.1578,830
840000,11.3374,840
850000,11.5965,850
860000,11.8614,860
870000,12.0717,870
880000,12.3858,880
890000,12.686,890
900000,13.0095,900
910000,13.2524,910
920000,13.4955,920
930000,13.9364,930
940000,14.2004,940
950000,14.5173,950
960000,14.7554,960
970000,15.1293,970
980000,15.4406,980
990000,15.7627,990
1000000,16.1673,1000"""

# Dividir el texto en líneas y luego dividir cada línea en valores separados por comas
lines = data_str.split('\n')

# Convertir los valores a punto flotante y generar una lista de listas
data = [[float(val) for val in line.split(',')] for line in lines]

# Convertir la lista de listas en un array de NumPy
data_array = np.array(data)

print(data_array)
# Out:
# [[1.00000e+04 9.00800e-03 1.00000e+01]
#  [2.00000e+04 2.09340e-02 2.00000e+01]
#  [3.00000e+04 2.82890e-02 3.00000e+01]
#  [4.00000e+04 3.12730e-02 4.00000e+01]
#  [5.00000e+04 3.94270e-02 5.00000e+01]
#  [6.00000e+04 5.68510e-02 6.00000e+01]
#  [7.00000e+04 7.73510e-02 7.00000e+01]
#  [8.00000e+04 1.05474e-01 8.00000e+01]
#  [9.00000e+04 1.30615e-01 9.00000e+01]
#  [1.00000e+05 1.57952e-01 1.00000e+02]
#  [1.10000e+05 1.91616e-01 1.10000e+02]
#  [1.20000e+05 2.28245e-01 1.20000e+02]
#  [1.30000e+05 2.68406e-01 1.30000e+02]
#  [1.40000e+05 3.09143e-01 1.40000e+02]
#  [1.50000e+05 3.55267e-01 1.50000e+02]
#  [1.60000e+05 4.03734e-01 1.60000e+02]
#  [1.70000e+05 4.55525e-01 1.70000e+02]
#  [1.80000e+05 5.10954e-01 1.80000e+02]
#  [1.90000e+05 5.69696e-01 1.90000e+02]
#  [2.00000e+05 6.31222e-01 2.00000e+02]
#  [2.10000e+05 7.00666e-01 2.10000e+02]
#  [2.20000e+05 7.76997e-01 2.20000e+02]
#  [2.30000e+05 8.36924e-01 2.30000e+02]
#  [2.40000e+05 9.12075e-01 2.40000e+02]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# GRAFICA PROMEDIOS I
data = np.array([
       [10000, 0.004563, 10],
    [20000, 0.014798, 20],
    [30000, 0.024069, 30],
    [40000, 0.030602, 40],
    [50000, 0.039877, 50],
    [60000, 0.056434, 60],
    [70000, 0.076371, 70],
    [80000, 0.099856, 80],
    [90000, 0.126257, 90],
    [100000, 0.155898, 100],
    [110000, 0.188927, 110],
    [120000, 0.224628, 120],
    [130000, 0.264509, 130],
    [140000, 0.305959, 140],
    [150000, 0.350913, 150],
    [160000, 0.400422, 160],
    [170000, 0.450728, 170],
    [180000, 0.505005, 180],
    [190000, 0.562693, 190],
    [200000, 0.626373, 200],
    [210000, 0.687606, 210],
    [220000, 0.757767, 220],
    [230000, 0.826045, 230],
    [240000, 0.897886, 240],
    [250000, 0.974187, 250],
    [260000, 1.05706, 260],
    [270000, 1.13717, 270],
    [280000, 1.222, 280],
    [290000, 1.31081, 290],
    [300000, 1.4028, 300],
    [310000, 1.49788, 310],
    [320000, 1.59611, 320],
    [330000, 1.69755, 330],
    [340000, 1.80192, 340],
    [350000, 1.90955, 350],
    [360000, 2.0202, 360],
    [370000, 2.15931, 370],
    [380000, 2.25844, 380],
    [390000, 2.37125, 390],
    [400000, 2.49571, 400],
    [410000, 2.62111, 410],
    [420000, 2.74974, 420],
    [430000, 2.88262, 430],
    [440000, 3.0681, 440],
    [450000, 3.15737, 450],
    [460000, 3.3004, 460],
    [470000, 3.44417, 470],
    [480000, 3.5939, 480],
    [490000, 3.74325, 490],
    [500000, 3.89748, 500],
    [510000, 4.05942, 510],
    [520000, 4.21579, 520],
    [530000, 4.37941, 530],
    [540000, 4.5461, 540],
    [550000, 4.71642, 550],
    [560000, 4.90988, 560],
    [570000, 5.16395, 570],
    [580000, 5.34458, 580],
    [590000, 5.43004, 590],
    [600000, 5.71399, 600],
    [610000, 5.86307, 610],
    [620000, 6.06752, 620],
    [630000, 6.26363, 630],
    [640000, 6.5193, 640],
    [650000, 6.68427, 650],
    [660000, 6.86356, 660],
    [670000, 7.06996, 670],
    [680000, 7.29945, 680],
    [690000, 7.55486, 690],
    [700000, 7.77499, 700],
    [710000, 7.97794, 710],
    [720000, 8.20996, 720],
    [730000, 8.39528, 730],
    [740000, 8.65631, 740],
    [750000, 8.86246, 750],
    [760000, 9.17962, 760],
    [770000, 9.42102, 770],
    [780000, 9.60513, 780],
    [790000, 9.84728, 790],
    [800000, 10.1267, 800],
    [810000, 10.4259, 810],
    [820000, 10.5746, 820],
    [830000, 10.8975, 830],
    [840000, 11.0374, 840],
    [850000, 11.4069, 850],
    [860000, 11.7054, 860],
    [870000, 11.955, 870],
    [880000, 12.2419, 880],
    [890000, 12.6336, 890],
    [900000, 13.0173, 900],
    [910000, 13.0527, 910],
    [920000, 13.3967, 920],
    [930000, 13.6405, 930],
    [940000, 13.885, 940],
    [950000, 14.2714, 950],
    [960000, 14.6033, 960],
    [970000, 14.9612, 970],
    [980000, 15.0018, 980],
    [990000, 15.3624, 990],
    [1000000, 15.8441, 1000]
])

dataII = data_array

nII = dataII[:, 1]
tiempoII = dataII[:, 1]


# Separar los datos en n y tiempo
n = data[:, 0]
tiempo = data[:, 1]

# Función de ajuste O(n*log(n))
def func(n, a, b):
    return a * n * n + b

# Ajuste de la curva
popt, pcov = curve_fit(func, n, tiempo)

# Parámetros del ajuste
a, b = popt

# Graficar datos experimentales y curva ajustada
plt.plot(n, tiempo, label='Estudio experimental: t(n) CASO I', color = 'blue', alpha = 0.5)
plt.plot(n, tiempoII, label='Estudio experimental: t(n) CASO II', color = 'red', alpha = 0.6)

#plt.plot(n, func(n, *popt)+0.7, color='red', label='Estudio teórico: O(n^2)', lw=1.3)#label=f'Ajuste: {a:.2f} * n * log(n) + {b:.2f}')
plt.xlabel('Tamaño de la cadena')
plt.ylabel('Tiempo (s)')
plt.title(f'Experimental: CASO PRUEBA I vs CASO PRUEBA II')
plt.legend()
plt.grid(true)
plt.show()
